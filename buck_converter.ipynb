# %%
from IPython.display import Markdown, display
import numpy as np

# %%
# Buck converter parameters
R_L     = 10e-3     # Inductor resistance   [Ohm]
L       = 5e-4      # Inductance            [H]
C       = 5.8e-4    # Capacitance           [F]
f_sw    = 10e3      # Switching frequency   [Hz]
V_in    = 13        # Input voltage         [V]
V_out   = 5         # Output voltage        [V]
R       = 3.5       # Load resistance       [Ohm]
mu      = 8e3       # Observer gain         [-]

table = f"""
| Parameter | Value | Description | Unit |
| --- | ---: | --- | --- |
| `R_L` | `{R_L}` | Inductor resistance | Ohm |
| `L` | `{L}` | Inductance | H |
| `C` | `{C}` | Capacitance | F |
| `f_sw` | `{f_sw}` | Switching frequency | Hz |
| `V_in` | `{V_in}` | Input voltage | V |
| `V_out` | `{V_out}` | Output voltage | V |
| `R` | `{R}` | Load resistance | Ohm |
"""

display(Markdown(table))
# Out:
# | Parameter | Value | Description | Unit |
# | --- | ---: | --- | --- |
# | `R_L` | `0.01` | Inductor resistance | Ohm |
# | `L` | `0.0005` | Inductance | H |
# | `C` | `0.00058` | Capacitance | F |
# | `f_sw` | `10000.0` | Switching frequency | Hz |
# | `V_in` | `13` | Input voltage | V |
# | `V_out` | `5` | Output voltage | V |
# | `R` | `3.5` | Load resistance | Ohm |
